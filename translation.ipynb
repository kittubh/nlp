# %%
# !pip -q install deep-translator
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.5 MB/s eta 0:00:00

# %%
from deep_translator import GoogleTranslator

# Input from the user
text = input("Enter text to translate: ")

# Source and target languages
source_lang = input("Enter source language (e.g., english, nepali, hindi): ").lower()
target_lang = input("Enter target language (e.g., french, spanish, japanese): ").lower()

# Translate
translated = GoogleTranslator(source=source_lang, target=target_lang).translate(text)

print("\nTranslated Text:")
print(translated)
# Out:
# Enter text to translate: im angry
# Enter source language (e.g., english, nepali, hindi): english
# Enter target language (e.g., french, spanish, japanese): french
#
# Translated Text:
# je suis en colère
