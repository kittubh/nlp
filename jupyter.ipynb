# %%
import nltk
immport string
from nltk.tokenize import word_tokenize
from nltk.corpus import stoopwords
from nltk.stem import PorterStemmer,wordnetLemmatizer
# Out:
#   Cell In[1], line 2
#     immport string
#             ^
# SyntaxError: invalid syntax
